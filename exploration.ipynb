# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("data-69d3709338fdb705334215.csv")
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced   84835.0        0
# 1         1        1961  Graduation         Single   57091.0        0
# 2     10476        1958  Graduation        Married   67267.0        0
# 3      1386        1967  Graduation       Together   32474.0        1
# 4      5371        1989  Graduation         Single   21474.0        1
# ...     ...         ...         ...            ...       ...      ...
# 2235  10142        1976         PhD       Divorced   66476.0        0
# 2236   5263        1977    2n Cycle        Married   31056.0        1
# 2237     22        1976  Graduation       Divorced   46310.0        1
# 2238    528        1978  Graduation        Married   65819.0        0
# 2239   4070        1969         PhD        Married   94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df.dtypes
# Out:
# ID                       int64
# Year_Birth               int64
# Education                  str
# Marital_Status             str
#  Income                float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer                str
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntBakedProds            int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# AcceptedCmp3             int64
# AcceptedCmp4             int64
# AcceptedCmp5             int64
# AcceptedCmp1             int64
# AcceptedCmp2             int64
# Response                 int64
# Complain                 int64
# Country                    str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   str
#  3   Marital_Status       2240 non-null   str
#  4    Income              2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   str
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntBakedProds        2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
# ...

# %%
print(df.nunique())
# Out:
# ID                     2240
# Year_Birth               59
# Education                 5
# Marital_Status            8
#  Income                1974
# Kidhome                   3
# Teenhome                  3
# Dt_Customer             663
# Recency                 100
# MntWines                776
# MntFruits               158
# MntMeatProducts         558
# MntFishProducts         182
# MntSweetProducts        177
# MntBakedProds           213
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        16
# AcceptedCmp3              2
# AcceptedCmp4              2
# AcceptedCmp5              2
# AcceptedCmp1              2
# AcceptedCmp2              2
# Response                  2
# Complain                  2
# Country                   8
# dtype: int64

# %%
# Stats de base 
df.describe()
# Out:
#                  ID   Year_Birth        Income       Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
# Nombre de valeurs manquantes par colonne
print(df.isnull().sum())

# Pourcentage de valeurs manquantes
missing_pct = df.isnull().mean() * 100
print(missing_pct[missing_pct > 0].sort_values(ascending=False))
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
#  Income                24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntBakedProds           0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64
# Income     1.071429
# dtype: float64

# %%
sns.countplot(df["Education"])
# Out:
# <Axes: xlabel='count', ylabel='Education'>

# %%
spend_cols = ["MntWines","MntFruits","MntMeatProducts",
              "MntFishProducts","MntSweetProducts","MntBakedProds"]
labels = ["Vins","Fruits","Viandes","Poissons","Sucreries","Boulangerie"]
means = df[spend_cols].mean()

plt.figure(figsize=(8, 4))
plt.barh(labels, means, color="steelblue")
plt.xlabel("Montant moyen ($)")
plt.title("Dépense moyenne par catégorie")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.boxplot(x="Response", y="Recency",
    data=df, palette=["steelblue","coral"])
plt.title("Recency selon réponse campagne")
plt.tight_layout(); plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7548\2677367489.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Response", y="Recency",

# %%
df["Kidhome"].value_counts().sort_index().plot(kind="bar", color="steelblue")
plt.title("Nombre d'enfants à la maison")
plt.xlabel("Kidhome")
plt.ylabel("Nb clients")
plt.show()

# %% [markdown]
# Interprétation : 58% des clients n'ont pas d'enfant. Ce groupe est le plus important et aussi celui qui dépense le plus — c'est le cœur de la clientèle à cibler en priorité.

# %%
df["NumStorePurchases"].value_counts().sort_index().plot(kind="bar", color="green")
plt.title("Achats en magasin par client")
plt.xlabel("NumStorePurchases")
plt.ylabel("Nb clients")
plt.show()

# %% [markdown]
# Interprétation : La majorité des clients fait 3 à 5 achats/mois en magasin. Le canal physique reste dominant — les campagnes en magasin ont un fort potentiel de reach.

# %%
df[" Income "].dropna().plot(kind="hist", bins=30, color="steelblue")
plt.title("Distribution du revenu")
plt.xlabel("Income ($)")
plt.show()

# %% [markdown]
# Interprétation : Distribution quasi normale centrée autour de 51 000.Unoutlieraˋ666666. Un outlier à 666 666
# .Unoutlieraˋ666666 est présent et doit être supprimé avant toute modélisation pour ne pas biaiser les résultats.

# %%
df["TotalSpend"] = df[spend_cols].sum(axis=1)
df["TotalSpend"].plot(kind="hist", bins=30, color="purple")
plt.title("Distribution des dépenses totales")
plt.xlabel("TotalSpend ($)")
plt.show()

# %% [markdown]
# Interprétation : Distribution bimodale — un grand groupe de petits acheteurs (0–200)etungroupedegrosclients(400–2500) et un groupe de gros clients (400–2500
# )etungroupedegrosclients(400–2500). Cela suggère l'existence de 2 segments bien distincts à explorer avec un clustering.

# %%
sns.boxplot(x="Kidhome", y="TotalSpend", data=df)
plt.title("Dépenses selon nombre d'enfants")
plt.xlabel("Kidhome")
plt.ylabel("TotalSpend ($)")
plt.show()

# %% [markdown]
# Interprétation : Les clients sans enfant dépensent en moyenne 901$ contre 205$ pour ceux avec 1 enfant. La présence d'enfants réduit fortement le budget consacré aux achats — variable très discriminante.

# %%
df.groupby("NumStorePurchases")[" Income "].mean().plot(kind="bar", color="teal")
plt.title("Revenu moyen selon achats en magasin")
plt.xlabel("NumStorePurchases")
plt.ylabel("Income moyen ($)")
plt.show()

# %% [markdown]
# Interprétation : Tendance croissante — plus le client est aisé, plus il fréquente les magasins physiques. Le canal magasin attire principalement les clients à revenus élevés.

# %%
plt.scatter(df[" Income "], df["TotalSpend"], alpha=0.3, color="steelblue")
plt.title("Income vs TotalSpend  (r=0.67)")
plt.xlabel("Income ($)")
plt.ylabel("TotalSpend ($)")
plt.show()

# %% [markdown]
# Interprétation : Corrélation positive forte (r=0.67) — le revenu est le principal moteur des dépenses. Les clients qui gagnent plus achètent significativement plus, ce qui en fait la variable la plus importante pour prédire le comportement d'achat.

# %%
#mesurer la force du lien entre Income et TotalSpend
from scipy import stats
corr, p_value = stats.pearsonr(
    df[" Income "].dropna(),
    df.loc[df[" Income "].notna(), "TotalSpend"])
print(f"Corrélation r : {corr:.3f}")
print(f"P-value : {p_value:.10f}")
if p_value < 0.05:
    print(f"Corrélation significative : r = {corr:.3f}")
# Out:
# Corrélation r : 0.668
# P-value : 0.0000000000
# Corrélation significative : r = 0.668

# %%
Lgroups = [df[df["Education"] == edu]["TotalSpend"]
          for edu in df["Education"].unique()]
f_stat, p_value = stats.f_oneway(*groups)
print(f"F-stat : {f_stat:.3f}")
print(f"P-value : {p_value:.20f}")

if p_value < 0.05:
    print("Au moins un groupe est significativement différent")
# Out:
# F-stat : 13.851
# P-value : 0.00000000003657678470
# Au moins un groupe est significativement différent

# %%
#test t-test comparasion 2 groupe 
group0 = df[df["Response"] == 0]["TotalSpend"]
group1 = df[df["Response"] == 1]["TotalSpend"]
t_stat, p_value = stats.ttest_ind(group0, group1)
print(f"T-stat : {t_stat:.3f}")
print(f"P-value : {p_value}")

if p_value < 0.05:
    print("Différence significative — Response influence TotalSpend")
else:
    print("Pas de différence significative")
# Out:
# T-stat : -13.017
# P-value : 2.1524131670755605e-37
# Différence significative — Response influence TotalSpend

# %%
#test chi2 pour deux variable catergorielle
from scipy.stats import chi2_contingency

table = pd.crosstab(df["Marital_Status"], df["Response"])
chi2, p_value, dof, expected = chi2_contingency(table)

print(f"Chi2 : {chi2:.3f}")
print(f"P-value : {p_value:.5f}")
print(f"Degrés de liberté : {dof}")

if p_value < 0.05:
    print("Relation significative entre Marital status et Response")
# Out:
# Chi2 : 54.242
# P-value : 0.00000
# Degrés de liberté : 7
# Relation significative entre Marital status et Response

# %%
df.groupby("Country")["TotalSpend"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
sns
